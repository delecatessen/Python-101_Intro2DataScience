# %%
name = "Richa"
print(name)
# Out:
# Richa

# %%
hobbies = ["dancing", "talking", "sleeping"]
print(hobbies)
print(hobbies[0])
print(hobbies[1])
# Out:
# ['dancing', 'talking', 'sleeping']
# dancing
# talking

# %%
my_name = "Oladele"
city = "London"
hobbies = ['dancing', 'eating', 'sleeping']
txt = f"My name is {my_name}. I live in {city}. My hobbies are: {hobbies[0]}, {hobbies[1]} and {hobbies[2]}."
print(txt)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 4
#       2 city = "London"
#       3 hobbies = ['dancing', 'eating', 'sleeping']
# ----> 4 txt = f"My name is {my_name}. I live in {city}. My hobbies are: {hobbies(0)}, {hobbies(1)} and {hobbies(2)}."
#       5 print(txt)
#
# TypeError: 'list' object is not callable
