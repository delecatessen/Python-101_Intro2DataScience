# %%
# Viewing what libraries/scripts are installed.
! pip list

# %%
# Installation of Spotipy library.
! pip install spotipy -- upgrade
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement upgrade (from versions: none)
# ERROR: No matching distribution found for upgrade

# %%
# Importing libraries.
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from api_keys import SPOTIPY_CLIENT_ID, SPOTIPY_CLIENT_SECRET

cid = SPOTIPY_CLIENT_ID #ClientID stored in referenced .py file.
secret = SPOTIPY_CLIENT_SECRET #ClientSecret stored in referenced .py file.

client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
artist_name = []
track_name = []
popularity = []
track_id = []
images = []

for i in range(0, 1000, 50): #(Start, Stop, Increment/Step)
    track_results = sp.search(q='year:2015', limit=50, offset=i, type='track', ) # hover over the search function to see the parameters, notice that we are searching for tracks in the year 2015
    for t in track_results['tracks']['items']:
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        images.append(t['album']['images'][0]['url'])
    
# Sorting the data into a dictionary: 'key : value'.
popular_tracks_dict = {'artist_name' : artist_name, 'track_name' : track_name, 'track_id' : track_id, 'popularity' : popularity, 'images' : images}

# %%
# Printing the above looped and collected data, but the format is not very legible.
print(popular_tracks_dict)
# Converting the data to a Pandas DataFrame for clearer analysis.
# Out:
# {'artist_name': ['Bryson Tiller', 'Chris Stapleton', 'Lord Huron', 'Bryson Tiller', 'Tame Impala', 'The Neighbourhood', 'Steve Lacy', 'The Weeknd', 'Kodak Black', 'Lil Peep', 'Twenty One Pilots', 'Beach House', 'Kendrick Lamar', 'Bryson Tiller', 'Pinegrove', 'Lil Peep', 'Future', 'Vundabar', '$uicideboy$', 'Twenty One Pilots', 'Travis Scott', 'Chris Stapleton', 'Travis Scott', '$uicideboy$', 'The Weeknd', 'Colter Wall', 'BØRNS', 'Mac Miller', '$uicideboy$', 'WILLOW', '$uicideboy$', 'Fall Out Boy', 'Bryson Tiller', 'Fetty Wap', 'Kali Uchis', 'Chris Stapleton', 'Mark Ronson', 'Justin Bieber', 'Shawn Mendes', 'The Weeknd', 'Tame Impala', 'A$AP Rocky', 'Leon Bridges', 'A$AP Rocky', 'Chase Atlantic', 'Justin Bieber', 'G-Eazy', 'Tame Impala', 'Big Sean', 'Thomas Rhett', 'The Weeknd', 'Bring Me The Horizon', 'Rich Homie Quan', 'Adele', 'Flo Rida', '$uicideboy$', 'Lana Del Rey', 'Coldplay', 'Tame Impala', 'Jeremih', 'Current Joys', 'Twenty One Pilots', 'Meghan Trainor', 'A$AP Rocky', 'Rihann
# ...

# %%
import pandas as pd
track_dataframe = pd.DataFrame({'artist_name' : artist_name, 'track_name' : track_name, 'track_id' : track_id, 'popularity' : popularity, 'images' : images})

# Printing the dimensions of the DataFrame.
print(track_dataframe.shape)

# Prints the first 5 records, if a number is not specified.
track_dataframe.head()
# Out:
# (1000, 5)
#             artist_name                 track_name                track_id  \
# 995       Ariana Grande                      Focus  1cdzfFjEbUbgTm5nv3FgXR
# 996  Hank Williams, Jr.  There's A Tear In My Beer  03IsQTh85NKrbTrc3MZU48
# 997    The Story So Far                      Nerve  1DlT3Udf11689ezYr6R8aA
# 998        Thomas Rhett                   Vacation  4DdF1l0DzBQy8YL2UVhPrU
# 999               Adele                  River Lea  3hwu7jZD2TjvWCeHzNlgSE
#
#      popularity                                             images
# 995          63  https://i.scdn.co/image/ab67616d0000b273d6ec80...
# 996          52  https://i.scdn.co/image/ab67616d0000b273296adb...
# 997          54  https://i.scdn.co/image/ab67616d0000b27356b73e...
# 998          52  https://i.scdn.co/image/ab67616d0000b273f00a1a...
# 999          56  https://i.scdn.co/image/ab67616d0000b27347ce40...

# %%
# Prints the last 5 records, if a number is not sepcified.
track_dataframe.tail()
# Both prints show that tracks are not orded by popularity.
# Out:
#             artist_name                 track_name                track_id  \
# 995       Ariana Grande                      Focus  1cdzfFjEbUbgTm5nv3FgXR
# 996  Hank Williams, Jr.  There's A Tear In My Beer  03IsQTh85NKrbTrc3MZU48
# 997    The Story So Far                      Nerve  1DlT3Udf11689ezYr6R8aA
# 998        Thomas Rhett                   Vacation  4DdF1l0DzBQy8YL2UVhPrU
# 999               Adele                  River Lea  3hwu7jZD2TjvWCeHzNlgSE
#
#      popularity                                             images
# 995          63  https://i.scdn.co/image/ab67616d0000b273d6ec80...
# 996          52  https://i.scdn.co/image/ab67616d0000b273296adb...
# 997          54  https://i.scdn.co/image/ab67616d0000b27356b73e...
# 998          52  https://i.scdn.co/image/ab67616d0000b273f00a1a...
# 999          56  https://i.scdn.co/image/ab67616d0000b27347ce40...
